# %%
import os

# %%
dir(os)
# Out:
# ['DirEntry',
#  'F_OK',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_putenv',
#  '_unsetenv',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
#  'devnull',
#  'dup',
#  'dup2',
#  'environ',
#  'errno',
#  'error',
#  'execl',
#  'execle',
# ...

# %%
os.name
# Out:
# 'nt'

# %%
os.environ
# Out:
# environ({'ALLUSERSPROFILE': 'C:\\ProgramData', 'APPDATA': 'C:\\Users\\light\\AppData\\Roaming', 'ASL.LOG': 'Destination=file', 'CCHZPATH': 'D:\\CTeX\\CTeX\\cct\\fonts', 'CCPKPATH': 'D:\\CTeX\\CTeX\\fonts\\pk\\modeless\\cct\\dpi$d', 'CLASSPATH': '.;C:\\Program Files (x86)\\Java\\jdk1.8.0_72\\bin;C:\\Program Files (x86)\\Java\\jdk1.8.0_72\\lib\\dt.jar;C:\\Program Files (x86)\\Java\\jdk1.8.0_72\\lib\\tools.jar', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'COMPUTERNAME': 'DESKTOP-3LA76T8', 'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe', 'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData', 'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer', 'FPS_BROWSER_USER_PROFILE_STRING': 'Default', 'GPU_FORCE_64BIT_PTR': '0', 'GPU_MAX_ALLOC_PERCENT': '100', 'GPU_MAX_HEAP_SIZE': '100', 'GPU_SINGLE_ALLOC_PERCENT': '100', 'GPU_USE_SYNC_OBJECTS': '1', 'HOME': 'C
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\light\\Desktop\\notes\\snippets\\lib'

# %%
os.chdir('c:/users/light/desktop')

# %%
os.getcwd()
# Out:
# 'c:\\users\\light\\desktop'

# %%
os.getenv('OS')
# Out:
# 'Windows_NT'

# %% [markdown]
# # Dir

# %%
os.mkdir('test')

# %%
os.path.exists('c:/users/light/desktop/test')
# Out:
# True

# %%
os.makedirs('./test/aa/bb/cc')

# %%
os.remove('./test')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-17-aa56532b5b4a> in <module>()
# ----> 1 os.remove('./test')
#
# PermissionError: [WinError 5] 拒绝访问。: './test'

# %%
os.rmdir('./test')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-18-f27c249e668c> in <module>()
# ----> 1 os.rmdir('./test')
#
# OSError: [WinError 145] 目录不是空的。: './test'

# %%
os.rename('./test', './pytest')

# %%
for root, dirs, files in os.walk('./'):
    print(root)
# Out:
# ./
# ./.tmp.drivedownload
# ./blogs
# ./blogs\e-hentai
# ./blogs\org2blog
# ./blogs\papers
# ./blogs\vps_php_accelator
# ./blogs\wp_built
# ./blogs\wp_widgets
# ./book
# ./coursera
# ./coursera\python data science
# ./coursera\python data science\1-intro
# ./coursera\python from zero
# ./coursera\python from zero\4-database
# ./coursera\python from zero\4-database\email_count
# ./coursera\python from zero\4-database\roster
# ./coursera\python from zero\4-database\roster\.vscode
# ./coursera\python from zero\4-database\tracks
# ./coursera\python from zero\5-capstone
# ./coursera\python from zero\5-capstone\geodata
# ./coursera\python from zero\5-capstone\geodata\geodata
# ./coursera\python from zero\5-capstone\geodata\geodata\.vscode
# ./coursera\python from zero\5-capstone\gmane
# ./coursera\python from zero\5-capstone\gmane\.idea
# ./coursera\python from zero\5-capstone\gmane\.idea\dataSources
# ./coursera\python from zero\5-capstone\gmane\.idea\inspectionProfiles
# ...

# %%
for root, dirs, files in os.walk('./', topdown=False):
    print(root)
# Out:
# ./.tmp.drivedownload
# ./blogs\e-hentai
# ./blogs\org2blog
# ./blogs\papers
# ./blogs\vps_php_accelator
# ./blogs\wp_built
# ./blogs\wp_widgets
# ./blogs
# ./book
# ./coursera\python data science\1-intro
# ./coursera\python data science
# ./coursera\python from zero\4-database\email_count
# ./coursera\python from zero\4-database\roster\.vscode
# ./coursera\python from zero\4-database\roster
# ./coursera\python from zero\4-database\tracks
# ./coursera\python from zero\4-database
# ./coursera\python from zero\5-capstone\geodata\geodata\.vscode
# ./coursera\python from zero\5-capstone\geodata\geodata
# ./coursera\python from zero\5-capstone\geodata
# ./coursera\python from zero\5-capstone\gmane\.idea\dataSources
# ./coursera\python from zero\5-capstone\gmane\.idea\inspectionProfiles
# ./coursera\python from zero\5-capstone\gmane\.idea
# ./coursera\python from zero\5-capstone\gmane\resources
# ./coursera\python from zero\5-capstone\gmane
# ...

# %%
for root, dirs, files in os.walk('./'):
    print(files)
# Out:
# ['desktop.ini', 'DittoSetup_64bit_3_21_223_0.exe', 'Eclipse Java Oxygen.lnk', 'Google 云端硬盘.lnk', 'Mages of Mystralia.url', 'NFS服务器.lnk', 'project_plan', 'proxyee-down - 快捷方式.lnk', 'PuTTY.lnk', 'RedisDesktopManager.lnk', 'Shadowsocks.lnk', 'The Witcher 3 Wild Hunt.url', 'Vivado 2014.4.lnk', '迅雷.lnk']
# []
# []
# ['cookie.PNG', 'ehentai.PNG', 'vnr.PNG', '捕获.PNG']
# ['12.jpg', 'example.html', 'example.org']
# ['smart_farm.org']
# ['eaccelerator.PNG', 'error.PNG', 'imagemagick.PNG', 'memcached.PNG', 'memcacheds.PNG', 'template.org', 'vps_blog.html', 'vps_blog.org', 'xcache.PNG', 'xcaches.PNG']
# ['ftp.PNG', 'godlight.cn.PNG', 'guidang.PNG', 'lnmp.PNG', 'org2blog.PNG', 'sidebar_boc.PNG', 'suc.PNG', 'toc+.PNG', 'TOC_settings.PNG', 'translate.PNG']
# ['wp_widgets.org']
# ['Android-App-Development-for-Human-Beings-ZENVA-ebooks.pdf', 'Deep-Learning-for-Human-Beings_v2.pdf', 'GTD.pdf', 'Java-Programming-for-Human-Beings.zip', 'webstorm.txt']
# []
# []
# ...

# %% [markdown]
# # Os.path

# %%
dir(os.path)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_get_bothseps',
#  '_getfinalpathname',
#  '_getfullpathname',
#  '_getvolumepathname',
#  'abspath',
#  'altsep',
#  'basename',
#  'commonpath',
#  'commonprefix',
#  'curdir',
#  'defpath',
#  'devnull',
#  'dirname',
#  'exists',
#  'expanduser',
#  'expandvars',
#  'extsep',
#  'genericpath',
#  'getatime',
#  'getctime',
#  'getmtime',
#  'getsize',
#  'isabs',
#  'isdir',
#  'isfile',
#  'islink',
#  'ismount',
#  'join',
#  'lexists',
#  'normcase',
#  'normpath',
#  'os',
#  'pardir',
#  'pathsep',
#  'realpath',
#  'relpath',
#  'samefile',
#  'sameopenfile',
#  'samestat',
#  'sep',
#  'split',
#  'splitdrive',
#  'splitext',
#  'splitunc',
#  'stat',
#  'supports_unicode_filenames',
#  'sys']

# %%
os.path.basename('c:/users/light/desktop')
# Out:
# 'desktop'

# %%
os.path.dirname("c:/users/light/desktop/pytest")
# Out:
# 'c:/users/light/desktop'

# %%
path='c:/users/light/desktop'
os.path.exists(path)
# Out:
# True

# %%
os.path.isdir(path)
# Out:
# True

# %%
os.path.isfile(path)
# Out:
# False

# %%
os.path.join(path, 'pytest')
# Out:
# 'c:/users/light/desktop\\pytest'

# %%
parts = ['c','users','light']
os.path.join(*parts)
# Out:
# 'c\\users\\light'

# %%
os.path.split(path)
# Out:
# ('c:/users/light', 'desktop')
